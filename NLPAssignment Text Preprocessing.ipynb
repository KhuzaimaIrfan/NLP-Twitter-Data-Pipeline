# %%
import tweepy
import pandas as pd
import time
import os
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
print(os.environ.get("AAAAAAAAAAAAAAAAAAAAAKKo4wEAAAAALQc1NE6z3LnczntB7yE0Y3SdPwQ%3DAe7FrXyFjU8qox323XYtKyA2lbQ38tCrNbdxyna1YA1TQcGLzl"))
# Out:
# None

# %%
# Replace with your credentials
api_key = '1e4kO6ldLN66S1aaC2RvK7OXH'
api_secret = 'Xr64GuGwwqw7oyxO6mo8NNg95Ho3gtbNtZ8nEzKOUFIm36W1kX'
access_token = '1979913128151220224-HisbRAIY0SzMbibnDxVmtmFoIPcpmF'
access_secret = '4qvp0qaYtb2Wi9AluEnt6byGWRVpmTIlwuq8pZXtG9Lll'

# Authentication
auth = tweepy.OAuth1UserHandler('1e4kO6ldLN66S1aaC2RvK7OXH', 'Xr64GuGwwqw7oyxO6mo8NNg95Ho3gtbNtZ8nEzKOUFIm36W1kX', '1979913128151220224-HisbRAIY0SzMbibnDxVmtmFoIPcpmF', '4qvp0qaYtb2Wi9AluEnt6byGWRVpmTIlwuq8pZXtG9Lll')
api = tweepy.API(auth)

try:
    user = api.verify_credentials()
    if user:
        print("✅ Authentication successful!")
except Exception as e:
    print("Authentication failed:", e)
# Out:
# ✅ Authentication successful!

# %%
# import tweepy

# bearer_token = "AAAAAAAAAAAAAAAAAAAAAKKo4wEAAAAAxJ7cTOZRhHpWDuA0h7ZnPjFjC48%3D6bhvCbT78so8ddf2ZywKCt4o8saHFOw35f2hSqv8sX8JjBSuCb"  # paste the token here
# client = tweepy.Client(bearer_token=bearer_token)

# # Test authentication
# try:
#     response = client.search_recent_tweets(query="AI", max_results=1)
#     print("✅ Authentication successful!")
# except tweepy.Unauthorized:
#     print("❌ 401 Unauthorized")

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAKKo4wEAAAAALQc1NE6z3LnczntB7yE0Y3SdPwQ%3DAe7FrXyFjU8qox323XYtKyA2lbQ38tCrNbdxyna1YA1TQcGLzl"
client = tweepy.Client(bearer_token=bearer_token)

query = "AI"
max_tweets = 20
tweets_data = []
next_token = None
fetched = 0

while fetched < max_tweets:
    try:
        response = client.search_recent_tweets(
            query=query,
            max_results=min(10, max_tweets - fetched),
            next_token=next_token
        )

        if response.data:
            tweets_data.extend(response.data)
            fetched += len(response.data)
            print(f"Fetched {fetched} tweets...")
        else:
            print("No more tweets available.")
            break

        next_token = response.meta.get("next_token")
        if not next_token:
            break

    except tweepy.TooManyRequests:
        print("Rate limit reached. Waiting 60 seconds...")
        time.sleep(15*60)
# Out:
# Fetched 10 tweets...
# Rate limit reached. Waiting 60 seconds...
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipython-input-4073874989.py in <cell line: 0>()
#      11     try:
# ---> 12         response = client.search_recent_tweets(
#      13             query=query,
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1275         params["query"] = query
# -> 1276         return self._make_request(
#    1277             "GET", "/2/tweets/search/recent", params=params,
#
# /usr/local/lib/python3.12/dist-packages/tweepy/client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     128
# --> 129         response = self.request(method, route, params=request_params,
#     130                                 json=json, user_auth=user_auth)
#
# ...

# %%
# Convert to DataFrame
tweet_list = [tweet.text for tweet in tweets_data]
df = pd.DataFrame(tweet_list, columns=['Text'])
print(df.head())
# Out:
#                                                 Text
# 0  @Mr_Hyde1866 Isso aí depende de diversas variá...
# 1                  @AdrianGuss34 @Kindred_AI 心智代币的起点
# 2  RT @Brumedemer: @moussya @DestinationTele Il a...
# 3  @oxmarvel_freak @davidgokhshtein Visa-linked U...
# 4  RT @skinnylcs: off nessa época os billiers gri...

# %%
import string
import re
# import emoji
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Remove HTML Tags
def remove_html_tags(text):
  clean = re.compile('<.*?>')
  return re.sub(clean, '', text)
df['clean_text'] = df['Text'].apply(remove_html_tags)
# print(df)

# %%
# Remove URLs
def remove_urls(text):
    return re.sub(r'http\S+|www\S+', '', text)

df['clean_text'] = df['clean_text'].apply(remove_urls)
# print(df)

# %%
# Remove punctuation
def remove_punctuations(text):
    return text.translate(str.maketrans('', '', string.punctuation))

df['clean_text'] = df['clean_text'].apply(remove_punctuations)

# %%
# Remove Numbers
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

df['clean_text'] = df['clean_text'].apply(remove_numbers)

# %%
# Replace emojis if there is any in the text
# !pip install emoji
import emoji
def replace_emojis(text):
    return emoji.demojize(text)
df['clean_text'] = df['clean_text'].apply(replace_emojis)

# %%
# Correct slangs & spelling mistakes
slang_dict = {"u":"you", "r":"are", "lol":"laughing out loud", "idk":"I don't know"}

def correct_slang(text):
    words = text.split()
    words = [slang_dict.get(word.lower(), word) for word in words]
    return ' '.join(words)

df['clean_text'] = df['clean_text'].apply(correct_slang)
print(df)
# Out:
#                                                 Text  \
# 0  @Mr_Hyde1866 Isso aí depende de diversas variá...
# 1                  @AdrianGuss34 @Kindred_AI 心智代币的起点
# 2  RT @Brumedemer: @moussya @DestinationTele Il a...
# 3  @oxmarvel_freak @davidgokhshtein Visa-linked U...
# 4  RT @skinnylcs: off nessa época os billiers gri...
# 5  @SavannahWatt @cysic_xyz interesting point on ...
# 6  RT @kccestrabaoo_: Eu amo esse vídeo. As duas ...
# 7              @Matt_Pinner Ai made. Nothing is real
# 8  @BagrescoreBr go RAFIL RADIO ACTIF Insta.We n ...
# 9  J’ai couper le live désolé, ça ne vas pas fort...
#
#                                           clean_text
# 0           MrHyde So a depends de diverse variáveis
# 1                       AdrianGuss KindredAI 心智代币的起点
# 2  of Brumedemer moussya DestinationTele Ll a dai...
# 3  oxmarvelfreak davidgokhshtein Visalinked USDT ...
# 4  of skinnylcs off ness epoch os tillers rings t...
# 5  SavannahWatt cysicxyz interesting point on the...
# ...

# %%
# For spelling correction you can use TextBlob library.
from textblob import TextBlob

def correct_spelling(text):
    return str(TextBlob(text).correct())

df['clean_text'] = df['clean_text'].apply(correct_spelling)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Tokenization
from nltk.tokenize import word_tokenize
def tokenize(text):
    return word_tokenize(text)

df['tokens'] = df['clean_text'].apply(tokenize)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-1047349634.py in <cell line: 0>()
#       4     return word_tokenize(text)
#       5
# ----> 6 df['tokens'] = df['clean_text'].apply(tokenize)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...
